# %%
import soundfile
import tensorflow as tf
import os
from os.path import isfile, join
import numpy as np
import shutil
from tensorflow import keras
from pathlib import Path
from IPython.display import display, Audio
import subprocess
from pydub import AudioSegment
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
directory = "C:\\Users\\ADMIN\\Desktop\\Voice\\DangCongNhat"
for file in os.listdir(directory):
    if(file.endswith('.wav')):
        nameSolo = file.rsplit('.', 1)[0]
        print(directory + nameSolo)
        data, samplerate = soundfile.read(directory + "\\" +file)
        
        soundfile.write('C:\\Users\\ADMIN\\Desktop\Voice\\' + nameSolo + '16BIT.wav', data, samplerate, subtype = 'PCM_16')
        print("converting " + file + "to 16-bit")
# Out:
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_00
# converting DangCongNhat_DangCongNhat_00.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_01
# converting DangCongNhat_DangCongNhat_01.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_02
# converting DangCongNhat_DangCongNhat_02.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_03
# converting DangCongNhat_DangCongNhat_03.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_04
# converting DangCongNhat_DangCongNhat_04.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_05
# converting DangCongNhat_DangCongNhat_05.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_06
# converting DangCongNhat_DangCongNhat_06.wavto 16-bit
# C:\Users\ADMIN\Desktop\Voice\DangCongNhatDangCongNhat_DangCongNhat_07
# ...
